# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
# Type 1: r.text
import requests

r = requests.get('https://api.github.com/events')
r.text
# 整個是一坨字串
# Out:
# "},"html":{"href":"https://github.com/HSAK5G/spotify-downloader/pull/16"},"issue":{"href":"https://api.github.com/repos/HSAK5G/spotify-downloader/issues/16"},"comments":{"href":"https://api.github.com/repos/HSAK5G/spotify-downloader/issues/16/comments"},"review_comments":{"href":"https://api.github.com/repos/HSAK5G/spotify-downloader/pulls/16/comments"},"review_comment":{"href":"https://api.github.com/repos/HSAK5G/spotify-downloader/pulls/comments{/number}"},"commits":{"href":"https://api.github.com/repos/HSAK5G/spotify-downloader/pulls/16/commits"},"statuses":{"href":"https://api.github.com/repos/HSAK5G/spotify-downloader/statuses/869581852ecbd1b13aa5faa5e8e2ff8d3c252a25"}},"author_association":"NONE","merged":true,"mergeable":null,"rebaseable":null,"mergeable_state":"unknown","merged_by":{"login":"pull[bot]","id":39814207,"node_id":"MDM6Qm90Mzk4MTQyMDc=","avatar_url":"https://avatars0.githubusercontent.com/in/12910?v=4","gravatar_id":"","url":"https://api.github.com/users/pull%5Bbot%5D","html_url":"https://github.com/apps/pull","followers_url":"https://api.github.com/users/pull%5Bbot%5D/followers","following_url":"https://api.github.com/users/pull%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/pull%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/pull%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/pull%5Bbot%5D/repos","events_url":"https://api.github.com/users/pull%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/pull%5Bbot%5D/received_events","type":"Bot","site_admin":false},"comments":0,"review_comments":0,"maintainer_can_modify":false,"commits":5,"additions":9,"deletions":4,"changed_files":3}},"public":true,"created_at":"2020-05-26T20:55:21Z"},{"id":"12445842818","type":"PushEvent","actor":{"id":33528173,"login":"Xcompanygames","display_login":"Xcompanygames","gravatar_id":"","url":"https://api.github.com/users/Xcompanygames","avatar_url":"https://avatars.githubusercontent.com/u/33528173?"},"repo":{"id":267112009,"name":"Xcompanygames/wargame-a","url":"https://api.github.com/repos/Xcompanygames/wargame-a"},"payload":{"push_id":5131991405,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"7b70167d998136e52a58dc0b9e350493ee1ad970","before":"95c3064424521fe27576e92313a7b1634462f8f1","commits":[{"sha":"7b70167d998136e52a58dc0b9e350493ee1ad970","author":{"email":"33528173+Xcompanygames@users.noreply.github.com","name":"Oriel"},"message":"Update FootCommander.cpp","distinct":true,"url":"https://api.github.com/repos/Xcompanygames/wargame-a/commits/7b70167d998136e52a58dc0b9e350493ee1ad970"}]},"public":true,"created_at":"2020-05-26T20:55:21Z"},{"id":"12445842820","type":"CreateEvent","actor":{"id":6165894,"login":"zhenyanghua","display_login":"zhenyanghua","gravatar_id":"","url":"https://api.github.com/users/zhenyanghua","avatar_url":"https://avatars.githubusercontent.com/u/6165894?"},"repo":{"id":262663091,"name":"zhenyanghua/react-grata","url":"https://api.github.com/repos/zhenyanghua/react-grata"},"payload":{"ref":"1.0.5","ref_type":"tag","master_branch":"master","description":"Light weight grid layout component. What you draw is what you get.","pusher_type":"user"},"public":true,"created_at":"2020-05-26T20:55:21Z"},{"id":"12445842815","type":"PushEvent","actor":{"id":54019549,"login":"mihajlo-perendija","display_login":"mihajlo-perendija","gravatar_id":"","url":"https://api.github.com/users/mihajlo-perendija","avatar_url":"https://avatars.githubusercontent.com/u/54019549?"},"repo":{"id":262627851,"name":"coperope/AT-WebCrawler","url":"https://api.github.com/repos/coperope/AT-WebCrawler"},"payload":{"push_id":5131991404,"size":1,"distinct_size":1,"ref":"refs/heads/feature/B-2.1_Initial_model","head":"acd4a89c217de7d1ecfc8768f64fd188826ca710","before":"6da6321ca22b2c0 ...

# %%
# Type 2: json.loads(r.text)
import json

json.loads(r.text)
# Out:
# url': 'https://api.github.com/users/Mugen87/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Mugen87/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'Fixed #19404.',
#     'created_at': '2020-05-26T09:33:45Z',
#     'updated_at': '2020-05-26T20:54:48Z',
#     'closed_at': '2020-05-26T20:54:48Z',
#     'merged_at': '2020-05-26T20:54:48Z',
#     'merge_commit_sha': '999d819e169ac143f24655a555b072469432df8d',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': {'url': 'https://api.github.com/repos/mrdoob/three.js/milestones/30',
#      'html_url': 'https://github.com/mrdoob/three.js/milestone/30',
#      'labels_url': 'https://api.github.com/repos/mrdoob/three.js/milestones/30/labels',
#      'id': 5236309,
#      'node_id': 'MDk6TWlsZXN0b25lNTIzNjMwOQ==',
#      'number': 30,
#      'title': 'r117',
#      'description': '',
#      'creator': {'login': 'mrdoob',
#       'id': 97088,
#       'node_id': 'MDQ6VXNlcjk3MDg4',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/97088?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mrdoob',
#       'html_url': 'https://github.com/mrdoob',
#       'followers_url': 'https://api.github.com/users/mrdoob/followers',
#       'following_url': 'https://api.github.com/users/mrdoob/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mrdoob/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mrdoob/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mrdoob/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mrdoob/orgs',
#       'repos_url': 'https://api.github.com/users/mrdoob/repos',
#       'events_url': 'https://api.github.com/users/mrdoob/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mrdoob/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 69,
#      'closed_issues': 110,
#      'state': 'open',
#      'created_at': '2020-03-25T14:05:32Z',
#      'updated_at': '2020-05-26T20:54:48Z',
#      'due_on': '2020-05-27T07:00:00Z',
#      'closed_at': None},
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/mrdoob/three.js/pulls/19466/commits',
#     'review_comments_url': 'https://api.github.com/repos/mrdoob/three.js/pulls/19466/comments',
#     'review_comment_url': 'https://api.github.com/repos/mrdoob/three.js/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mrdoob/three.js/issues/19466/comments',
#     'statuses_url': 'https://api.github.com/repos/mrdoob/three.js/statuses/8a36de0a21f286de85b8351f13f12bde76700755',
#     'head': {'label': 'Mugen87:dev49',
#      'ref': 'dev49',
#      'sha': '8a36de0a21f286de85b8351f13f12bde76700755',
#      'user': {'login': 'Mugen87',
#       'id': 12612165,
#       'node_id': 'MDQ6VXNlcjEyNjEyMTY1',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/12612165?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Mugen87',
#       'html_url': 'https://github.com/Mugen87',
#       'followers_url': 'https://api.github.com/users/Mugen87/followers',
#       'following_url': 'https://api.github.com/users/Mugen87/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Mugen87/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Mugen87/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Mugen87/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Mugen87/orgs',
#       'repos_url': 'https://api.github.com/users/Mugen87/repos',
#       'events_url': 'https://api.github.com/users/Mugen87/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Mugen87/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 44012154,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0NDAxMjE1NA==',
#       'name': 'three.js',
#       'full_name': 'Mugen87/three.js',
#       'private': False,
#       'owner': {'login': 'Mugen87',
#        'id': 12612165,
#        'node_id': 'MDQ6VXNlcjEyNjEyMTY1',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/12612165?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Mugen87',
#        'html_url': 'https://github.com/Mugen87',
#        'followers_url': 'https://api.github.com/users/Mugen87/followers',
#        'following_url': 'https://api.github.com/users/Mugen87/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Mugen87/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Mugen87/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Mugen87/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Mugen87/orgs',
#        'repos_url': 'https://api.github.com/users/Mugen87/repos',
#        'events_url': 'https://api.github.com/users/Mugen87/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Mugen87/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Mugen87/three.js',
#       'description': 'JavaScript 3D library.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/Mugen87/three.js',
#       'forks_url': 'https://api.github.com/repos/Mugen87/three.js/forks',
#       'keys_url': 'https://api.github.com/repos/Mugen87/three.js/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Mugen87/three.js/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Mugen87/three.js/teams',
#       'hooks_url': 'https://api.github.com/repos/Mugen87/three.js/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Mugen87/three.js/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Mugen87/three.js/events',
#       'assignees_url': 'https://api.github.com/repos/Mugen87/three.js/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Mugen87/three.js/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Mugen87/three.js/tags',
#       'blobs_url': 'https://api.github.com/repos/Mugen87/three.js/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Mugen87/three.js/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Mugen87/three.js/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Mugen87/three.js/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Mugen87/three.js/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Mugen87/three.js/languages',
#       'stargazers_url': 'https://api.github.com/repos/Mugen87/three.js/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Mugen87/three.js/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Mugen87/three.js/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Mugen87/three.js/subscription',
#       'commits_url': 'https://api.github.com/repos/Mugen87/three.js/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Mugen87/three.js/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Mugen87/three.js/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Mugen87/three.js/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Mugen87/three.js/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Mugen87/three.js/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Mugen87/three.js/merges',
#       'archive_url': 'https://api.github.com/repos/Mugen87/three.js/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Mugen87/three.js/downloads',
#       'issues_url': 'https://api.github.com/repos/Mugen87/three.js/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Mugen87/three.js/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Mugen87/three.js/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Mugen87/three.js/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Mugen87/three.js/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Mugen87/three.js/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Mugen87/three.js/deployments',
#       'created_at': '2015-10-10T13:41:49Z',
#       'updated_at': '2020-05-25T14:20:10Z',
#       'pushed_at': '2020-05-26T19:41:54Z',
#       'git_url': 'git://github.com/Mugen87/three.js.git',
#       'ssh_url': 'git@github.com:Mugen87/three.js.git',
#       'clone_url': 'https://github.com/Mugen87/three.js.git',
#       'svn_url': 'https://github.com/Mugen87/three.js',
#       'homepage': 'https://threejs.org/',
#       'size': 883141,
#       'stargazers_count': 7,
#       'watchers_count': 7,
#       'language': 'JavaScript',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 1,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 1,
#       'open_issues': 0,
#       'watchers': 7,
#       'default_branch': 'master'}},
#     'base': {'label': 'mrdoob:dev',
#      'ref': 'dev',
#      'sha': '3bff49372e596cea09969d1f5fa081f9a1d00e1a',
#      'user': {'login': 'mrdoob',
#       'id': 97088,
#       'node_id': 'MDQ6VXNlcjk3MDg4',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/97088?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mrdoob',
#       'html_url': 'https://github.com/mrdoob',
#       'followers_url': 'https://api.github.com/users/mrdoob/followers',
#       'following_url': 'https://api.github.com/users/mrdoob/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mrdoob/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mrdoob/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mrdoob/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mrdoob/orgs',
#       'repos_url': 'https://api.github.com/users/mrdoob/repos',
#       'events_url': 'https://api.github.com/users/mrdoob/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mrdoob/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 576201,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk1NzYyMDE=',
#       'name': 'three.js',
#       'full_name': 'mrdoob/three.js',
#       'private': False,
#       'owner': {'login': 'mrdoob',
#        'id': 97088,
#        'node_id': 'MDQ6VXNlcjk3MDg4',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/97088?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mrdoob',
#        'html_url': 'https://github.com/mrdoob',
#        'followers_url': 'https://api.github.com/users/mrdoob/followers',
#        'following_url': 'https://api.github.com/users/mrdoob/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mrdoob/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mrdoob/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mrdoob/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mrdoob/orgs',
#        'repos_url': 'https://api.github.com/users/mrdoob/repos',
#        'events_url': 'https://api.github.com/users/mrdoob/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mrdoob/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mrdoob/three.js',
#       'description': 'JavaScript 3D library.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/mrdoob/three.js',
#       'forks_url': 'https://api.github.com/repos/mrdoob/three.js/forks',
#       'keys_url': 'https://api.github.com/repos/mrdoob/three.js/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mrdoob/three.js/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mrdoob/three.js/teams',
#       'hooks_url': 'https://api.github.com/repos/mrdoob/three.js/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mrdoob/three.js/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mrdoob/three.js/events',
#       'assignees_url': 'https://api.github.com/repos/mrdoob/three.js/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mrdoob/three.js/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mrdoob/three.js/tags',
#       'blobs_url': 'https://api.github.com/repos/mrdoob/three.js/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mrdoob/three.js/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mrdoob/three.js/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mrdoob/three.js/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mrdoob/three.js/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mrdoob/three.js/languages',
#       'stargazers_url': 'https://api.github.com/repos/mrdoob/three.js/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mrdoob/three.js/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mrdoob/three.js/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mrdoob/three.js/subscription',
#       'commits_url': 'https://api.github.com/repos/mrdoob/three.js/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mrdoob/three.js/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mrdoob/three.js/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mrdoob/three.js/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mrdoob/three.js/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mrdoob/three.js/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mrdoob/three.js/merges',
#       'archive_url': 'https://api.github.com/repos/mrdoob/three.js/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mrdoob/three.js/downloads',
#       'issues_url': 'https://api.github.com/repos/mrdoob/three.js/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mrdoob/three.js/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mrdoob/three.js/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mrdoob/three.js/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mrdoob/three.js/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mrdoob/three.js/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mrdoob/three.js/deployments',
#       'created_at': '2010-03-23T18:58:01Z',
#       'updated_at': '2020-05-26T20:39:06Z',
#       'pushed_at': '2020-05-26T20:54:47Z',
#       'git_url': 'git://github.com/mrdoob/three.js.git',
#       'ssh_url': 'git@github.com:mrdoob/three.js.git',
#       'clone_url': 'https://github.com/mrdoob/three.js.git',
#       'svn_url': 'https://github.com/mrdoob/three.js',
#       'homepage': 'https://threejs.org/',
#       'size': 887473,
#       'stargazers_count': 60886,
#       'watchers_count': 60886,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': False,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 23701,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 562,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 23701,
#       'open_issues': 562,
#       'watchers': 60886,
#       'default_branch': 'dev'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mrdoob/three.js/pulls/19466'},
#      'html': {'href': 'https://github.com/mrdoob/three.js/pull/19466'},
#      'issue': {'href': 'https://api.github.com/repos/mrdoob/three.js/issues/19466'},
#      'comments': {'href': 'https://api.github.com/repos/mrdoob/three.js/issues/19466/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mrdoob/three.js/pulls/19466/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mrdoob/three.js/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mrdoob/three.js/pulls/19466/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mrdoob/three.js/statuses/8a36de0a21f286de85b8351f13f12bde76700755'}},
#     'author_association': 'COLLABORATOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'mrdoob',
#      'id': 97088,
#      'node_id': 'MDQ6VXNlcjk3MDg4',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/97088?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mrdoob',
#      'html_url': 'https://github.com/mrdoob',
#      'followers_url': 'https://api.github.com/users/mrdoob/followers',
#      'following_url': 'https://api.github.com/users/mrdoob/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mrdoob/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mrdoob/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mrdoob/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mrdoob/orgs',
#      'repos_url': 'https://api.github.com/users/mrdoob/repos',
#      'events_url': 'https://api.github.com/users/mrdoob/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mrdoob/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 945,
#     'deletions': 71,
#     'changed_files': 53}},
#   'public': True,
#   'created_at': '2020-05-26T20:54:49Z'},
#  {'id': '12445838203',
#   'type': 'PushEvent',
#   'actor': {'id': 22410,
#    'login': 'eyberg',
#    'display_login': 'eyberg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/eyberg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22410?'},
#   'repo': {'id': 148196645,
#    'name': 'nanovms/ops',
#    'url': 'https://api.github.com/repos/nanovms/ops'},
#   'payload': {'push_id': 5131989057,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/vsphere',
#    'head': '57892d2ee49c026c6d6ac34bec6aa8a152e4a315',
#    'before': '5914a324d98434b4b0670c064545586e248a3c7e',
#    'commits': [{'sha': '6ab496fffba87af607899eb4225e6e8381eca0b0',
#      'author': {'email': 'ian@deferpanic.com', 'name': 'Ian Eyberg'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nanovms/ops/commits/6ab496fffba87af607899eb4225e6e8381eca0b0'},
#     {'sha': '0e970d768af25b59ed64a4711b82d90eac9c2f91',
#      'author': {'email': 'ian@deferpanic.com', 'name': 'Ian Eyberg'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nanovms/ops/commits/0e970d768af25b59ed64a4711b82d90eac9c2f91'},
#     {'sha': '57892d2ee49c026c6d6ac34bec6aa8a152e4a315',
#      'author': {'email': 'ian@deferpanic.com', 'name': 'Ian Eyberg'},
#      'message': '.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nanovms/ops/commits/57892d2ee49c026c6d6ac34bec6aa8a152e4a315'}]},
#   'public': True,
#   'created_at': '2020-05-26T20:54:49Z',
#   'org': {'id': 38020270,
#    'login': 'nanovms',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/nanovms',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38020270?'}}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json

payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://api.github.com/events', params = payload)
json.loads(r.text)
# Out:
# 99333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 66000771,
#    'name': 'all-of-us/raw-data-repository',
#    'url': 'https://api.github.com/repos/all-of-us/raw-data-repository'},
#   'payload': {'ref': 'dependabot/pip/httplib2-0.18.0',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-26T21:04:26Z',
#   'org': {'id': 22846942,
#    'login': 'all-of-us',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/all-of-us',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22846942?'}},
#  {'id': '12445921445',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 25904340,
#    'login': 'bert-e',
#    'display_login': 'bert-e',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bert-e',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25904340?'},
#   'repo': {'id': 42728835,
#    'name': 'scality/Arsenal',
#    'url': 'https://api.github.com/repos/scality/Arsenal'},
#   'payload': {'action': 'closed',
#    'number': 1054,
#    'pull_request': {'url': 'https://api.github.com/repos/scality/Arsenal/pulls/1054',
#     'id': 423451351,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDIzNDUxMzUx',
#     'html_url': 'https://github.com/scality/Arsenal/pull/1054',
#     'diff_url': 'https://github.com/scality/Arsenal/pull/1054.diff',
#     'patch_url': 'https://github.com/scality/Arsenal/pull/1054.patch',
#     'issue_url': 'https://api.github.com/repos/scality/Arsenal/issues/1054',
#     'number': 1054,
#     'state': 'closed',
#     'locked': False,
#     'title': 'INTEGRATION [PR#1052 > development/8.1] feature: S3C-2944 put object legal hold',
#     'user': {'login': 'bert-e',
#      'id': 25904340,
#      'node_id': 'MDQ6VXNlcjI1OTA0MzQw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/25904340?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bert-e',
#      'html_url': 'https://github.com/bert-e',
#      'followers_url': 'https://api.github.com/users/bert-e/followers',
#      'following_url': 'https://api.github.com/users/bert-e/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bert-e/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bert-e/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bert-e/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bert-e/orgs',
#      'repos_url': 'https://api.github.com/users/bert-e/repos',
#      'events_url': 'https://api.github.com/users/bert-e/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bert-e/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'This pull request has been created automatically.\nIt is linked to its parent pull request #1052.\n\n**Do not edit this pull request directly.**\nIf you need to amend/cancel the changeset on branch\n`w/8.1/feature/S3C-2944_putObjectLegalHold`, please follow this\nprocedure:\n\n```bash\n $ git fetch\n $ git checkout w/8.1/feature/S3C-2944_putObjectLegalHold\n $ # <amend or cancel the changeset by _adding_ new commits>\n $ git push origin w/8.1/feature/S3C-2944_putObjectLegalHold\n```\n\nPlease always comment pull request #1052 instead of this one.',
#     'created_at': '2020-05-26T20:38:55Z',
#     'updated_at': '2020-05-26T21:04:25Z',
#     'closed_at': '2020-05-26T21:04:25Z',
#     'merged_at': None,
#     'merge_commit_sha': '269f95a5f99e6cce3fee6073a32e149645652602',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/scality/Arsenal/pulls/1054/commits',
#     'review_comments_url': 'https://api.github.com/repos/scality/Arsenal/pulls/1054/comments',
#     'review_comment_url': 'https://api.github.com/repos/scality/Arsenal/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/scality/Arsenal/issues/1054/comments',
#     'statuses_url': 'https://api.github.com/repos/scality/Arsenal/statuses/4eca80a3151bbb355a492cbb21263acb4848dc76',
#     'head': {'label': 'scality:w/8.1/feature/S3C-2944_putObjectLegalHold',
#      'ref': 'w/8.1/feature/S3C-2944_putObjectLegalHold',
#      'sha': '4eca80a3151bbb355a492cbb21263acb4848dc76',
#      'user': {'login': 'scality',
#       'id': 383812,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4MzgxMg==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/383812?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/scality',
#       'html_url': 'https://github.com/scality',
#       'followers_url': 'https://api.github.com/users/scality/followers',
#       'following_url': 'https://api.github.com/users/scality/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/scality/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/scality/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/scality/subscriptions',
#       'organizations_url': 'https://api.github.com/users/scality/orgs',
#       'repos_url': 'https://api.github.com/users/scality/repos',
#       'events_url': 'https://api.github.com/users/scality/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/scality/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 42728835,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MjcyODgzNQ==',
#       'name': 'Arsenal',
#       'full_name': 'scality/Arsenal',
#       'private': False,
#       'owner': {'login': 'scality',
#        'id': 383812,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4MzgxMg==',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/383812?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/scality',
#        'html_url': 'https://github.com/scality',
#        'followers_url': 'https://api.github.com/users/scality/followers',
#        'following_url': 'https://api.github.com/users/scality/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/scality/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/scality/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/scality/subscriptions',
#        'organizations_url': 'https://api.github.com/users/scality/orgs',
#        'repos_url': 'https://api.github.com/users/scality/repos',
#        'events_url': 'https://api.github.com/users/scality/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/scality/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/scality/Arsenal',
#       'description': 'Common utilities for the open-source Scality S3 project components',
#       'fork': False,
#       'url': 'https://api.github.com/repos/scality/Arsenal',
#       'forks_url': 'https://api.github.com/repos/scality/Arsenal/forks',
#       'keys_url': 'https://api.github.com/repos/scality/Arsenal/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/scality/Arsenal/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/scality/Arsenal/teams',
#       'hooks_url': 'https://api.github.com/repos/scality/Arsenal/hooks',
#       'issue_events_url': 'https://api.github.com/repos/scality/Arsenal/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/scality/Arsenal/events',
#       'assignees_url': 'https://api.github.com/repos/scality/Arsenal/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/scality/Arsenal/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/scality/Arsenal/tags',
#       'blobs_url': 'https://api.github.com/repos/scality/Arsenal/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/scality/Arsenal/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/scality/Arsenal/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/scality/Arsenal/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/scality/Arsenal/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/scality/Arsenal/languages',
#       'stargazers_url': 'https://api.github.com/repos/scality/Arsenal/stargazers',
#       'contributors_url': 'https://api.github.com/repos/scality/Arsenal/contributors',
#       'subscribers_url': 'https://api.github.com/repos/scality/Arsenal/subscribers',
#       'subscription_url': 'https://api.github.com/repos/scality/Arsenal/subscription',
#       'commits_url': 'https://api.github.com/repos/scality/Arsenal/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/scality/Arsenal/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/scality/Arsenal/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/scality/Arsenal/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/scality/Arsenal/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/scality/Arsenal/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/scality/Arsenal/merges',
#       'archive_url': 'https://api.github.com/repos/scality/Arsenal/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/scality/Arsenal/downloads',
#       'issues_url': 'https://api.github.com/repos/scality/Arsenal/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/scality/Arsenal/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/scality/Arsenal/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/scality/Arsenal/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/scality/Arsenal/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/scality/Arsenal/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/scality/Arsenal/deployments',
#       'created_at': '2015-09-18T14:58:21Z',
#       'updated_at': '2020-05-21T22:42:55Z',
#       'pushed_at': '2020-05-26T21:04:24Z',
#       'git_url': 'git://github.com/scality/Arsenal.git',
#       'ssh_url': 'git@github.com:scality/Arsenal.git',
#       'clone_url': 'https://github.com/scality/Arsenal.git',
#       'svn_url': 'https://github.com/scality/Arsenal',
#       'homepage': '',
#       'size': 2595,
#       'stargazers_count': 8,
#       'watchers_count': 8,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 12,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 28,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 12,
#       'open_issues': 28,
#       'watchers': 8,
#       'default_branch': 'development/8.1'}},
#     'base': {'label': 'scality:development/8.1',
#      'ref': 'development/8.1',
#      'sha': '36b68be05196a1233d630b59f54e5b79964057ad',
#      'user': {'login': 'scality',
#       'id': 383812,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4MzgxMg==',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/383812?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/scality',
#       'html_url': 'https://github.com/scality',
#       'followers_url': 'https://api.github.com/users/scality/followers',
#       'following_url': 'https://api.github.com/users/scality/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/scality/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/scality/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/scality/subscriptions',
#       'organizations_url': 'https://api.github.com/users/scality/orgs',
#       'repos_url': 'https://api.github.com/users/scality/repos',
#       'events_url': 'https://api.github.com/users/scality/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/scality/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 42728835,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk0MjcyODgzNQ==',
#       'name': 'Arsenal',
#       'full_name': 'scality/Arsenal',
#       'private': False,
#       'owner': {'login': 'scality',
#        'id': 383812,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4MzgxMg==',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/383812?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/scality',
#        'html_url': 'https://github.com/scality',
#        'followers_url': 'https://api.github.com/users/scality/followers',
#        'following_url': 'https://api.github.com/users/scality/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/scality/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/scality/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/scality/subscriptions',
#        'organizations_url': 'https://api.github.com/users/scality/orgs',
#        'repos_url': 'https://api.github.com/users/scality/repos',
#        'events_url': 'https://api.github.com/users/scality/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/scality/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/scality/Arsenal',
#       'description': 'Common utilities for the open-source Scality S3 project components',
#       'fork': False,
#       'url': 'https://api.github.com/repos/scality/Arsenal',
#       'forks_url': 'https://api.github.com/repos/scality/Arsenal/forks',
#       'keys_url': 'https://api.github.com/repos/scality/Arsenal/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/scality/Arsenal/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/scality/Arsenal/teams',
#       'hooks_url': 'https://api.github.com/repos/scality/Arsenal/hooks',
#       'issue_events_url': 'https://api.github.com/repos/scality/Arsenal/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/scality/Arsenal/events',
#       'assignees_url': 'https://api.github.com/repos/scality/Arsenal/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/scality/Arsenal/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/scality/Arsenal/tags',
#       'blobs_url': 'https://api.github.com/repos/scality/Arsenal/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/scality/Arsenal/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/scality/Arsenal/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/scality/Arsenal/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/scality/Arsenal/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/scality/Arsenal/languages',
#       'stargazers_url': 'https://api.github.com/repos/scality/Arsenal/stargazers',
#       'contributors_url': 'https://api.github.com/repos/scality/Arsenal/contributors',
#       'subscribers_url': 'https://api.github.com/repos/scality/Arsenal/subscribers',
#       'subscription_url': 'https://api.github.com/repos/scality/Arsenal/subscription',
#       'commits_url': 'https://api.github.com/repos/scality/Arsenal/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/scality/Arsenal/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/scality/Arsenal/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/scality/Arsenal/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/scality/Arsenal/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/scality/Arsenal/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/scality/Arsenal/merges',
#       'archive_url': 'https://api.github.com/repos/scality/Arsenal/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/scality/Arsenal/downloads',
#       'issues_url': 'https://api.github.com/repos/scality/Arsenal/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/scality/Arsenal/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/scality/Arsenal/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/scality/Arsenal/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/scality/Arsenal/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/scality/Arsenal/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/scality/Arsenal/deployments',
#       'created_at': '2015-09-18T14:58:21Z',
#       'updated_at': '2020-05-21T22:42:55Z',
#       'pushed_at': '2020-05-26T21:04:24Z',
#       'git_url': 'git://github.com/scality/Arsenal.git',
#       'ssh_url': 'git@github.com:scality/Arsenal.git',
#       'clone_url': 'https://github.com/scality/Arsenal.git',
#       'svn_url': 'https://github.com/scality/Arsenal',
#       'homepage': '',
#       'size': 2595,
#       'stargazers_count': 8,
#       'watchers_count': 8,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 12,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 28,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'forks': 12,
#       'open_issues': 28,
#       'watchers': 8,
#       'default_branch': 'development/8.1'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/scality/Arsenal/pulls/1054'},
#      'html': {'href': 'https://github.com/scality/Arsenal/pull/1054'},
#      'issue': {'href': 'https://api.github.com/repos/scality/Arsenal/issues/1054'},
#      'comments': {'href': 'https://api.github.com/repos/scality/Arsenal/issues/1054/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/scality/Arsenal/pulls/1054/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/scality/Arsenal/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/scality/Arsenal/pulls/1054/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/scality/Arsenal/statuses/4eca80a3151bbb355a492cbb21263acb4848dc76'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 216,
#     'deletions': 4,
#     'changed_files': 6}},
#   'public': True,
#   'created_at': '2020-05-26T21:04:26Z',
#   'org': {'id': 383812,
#    'login': 'scality',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/scality',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/383812?'}},
#  {'id': '12445921439',
#   'type': 'DeleteEvent',
#   'actor': {'id': 4944099,
#    'login': 'NGL321',
#    'display_login': 'NGL321',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NGL321',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4944099?'},
#   'repo': {'id': 3251639,
#    'name': 'aws/aws-sdk-net',
#    'url': 'https://api.github.com/repos/aws/aws-sdk-net'},
#   'payload': {'ref': 'add_stale_action',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-26T21:04:26Z',
#   'org': {'id': 2232217,
#    'login': 'aws',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/aws',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2232217?'}}]
