# %% [markdown]
# # Python 下載XML檔案與解析
#
#
# * 了解 xml 檔案格式與內容
# * 能夠利用套件存取 xml 格式的檔案

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異
#
# * 根據範例檔案的結果：
#     1. 請問高雄市有多少地區有溫度資料？
#     2. 請取出每一個地區所記錄的第一個時間點跟溫度
#     3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %% [markdown]
# ### 比較一下範例檔案中的「File I/O」與「xmltodict」讀出來的內容有什麼差異

# %% [markdown]
# ### 根據範例檔案的結果：
#
# 1. 請問高雄市有多少地區有溫度資料？
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

# %%
fh = open("./data/64_72hr_CH.xml", "r", encoding = "utf-8")
xml = fh.read()
fh.close()

# xml

# %%
# 解析
import xmltodict
d = dict(xmltodict.parse(xml))

# %%
# 1. 請問高雄市有多少地區有溫度資料？

location = d["cwbopendata"]["dataset"]["locations"]["location"]
print(len(loaction))
# Out:
# 38

# %%
# 2. 請取出每一個地區所記錄的第一個時間點跟溫度

for key in location:
    time = key["weatherElement"][0]["time"][0]["dataTime"]
    temp = key["weatherElement"][0]["time"][0]["elementValue"]["value"]
    types = key["weatherElement"][0]["time"][0]["elementValue"]["measures"]
    
    print(key["locationName"] + ": " + time + ", " + temp + types)
# Out:
# 鹽埕區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 鼓山區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 左營區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 楠梓區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 三民區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 新興區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 前金區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 苓雅區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 前鎮區: 2020-05-21T12:00:00+08:00, 28攝氏度
# 旗津區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 小港區: 2020-05-21T12:00:00+08:00, 28攝氏度
# 鳳山區: 2020-05-21T12:00:00+08:00, 28攝氏度
# 林園區: 2020-05-21T12:00:00+08:00, 28攝氏度
# 大寮區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 大樹區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 大社區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 仁武區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 鳥松區: 2020-05-21T12:00:00+08:00, 28攝氏度
# 岡山區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 橋頭區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 燕巢區: 2020-05-21T12:00:00+08:00, 26攝氏度
# 田寮區: 2020-05-21T12:00:00+08:00, 26攝氏度
# 阿蓮區: 2020-05-21T12:00:00+08:00, 26攝氏度
# 路竹區: 2020-05-21T12:00:00+08:00, 27攝氏度
# 湖內區: 2020-05-21T12:00:00+08:00, 27攝氏度
# ...

# %%
# 3. 請取出第一個地區所記錄的每一個時間點跟溫度

print(location[0]["locationName"])
i = 0
for key in location[0]["weatherElement"]:
    for key2 in key["time"]:
        if key["description"] == "溫度":
            time = key["time"][i]["dataTime"]
            temp = key["time"][i]["elementValue"]["value"]
            types = key["time"][i]["elementValue"]["measures"]
            print(time + ": " + temp + types)
            i += 1
# Out:
# 鹽埕區
# 2020-05-21T12:00:00+08:00: 27攝氏度
# 2020-05-21T15:00:00+08:00: 29攝氏度
# 2020-05-21T18:00:00+08:00: 28攝氏度
# 2020-05-21T21:00:00+08:00: 27攝氏度
# 2020-05-22T00:00:00+08:00: 26攝氏度
# 2020-05-22T03:00:00+08:00: 26攝氏度
# 2020-05-22T06:00:00+08:00: 25攝氏度
# 2020-05-22T09:00:00+08:00: 28攝氏度
# 2020-05-22T12:00:00+08:00: 29攝氏度
# 2020-05-22T15:00:00+08:00: 29攝氏度
# 2020-05-22T18:00:00+08:00: 28攝氏度
# 2020-05-22T21:00:00+08:00: 27攝氏度
# 2020-05-23T00:00:00+08:00: 27攝氏度
# 2020-05-23T03:00:00+08:00: 26攝氏度
# 2020-05-23T06:00:00+08:00: 26攝氏度
# 2020-05-23T09:00:00+08:00: 28攝氏度
# 2020-05-23T12:00:00+08:00: 29攝氏度
# 2020-05-23T15:00:00+08:00: 29攝氏度
# 2020-05-23T18:00:00+08:00: 28攝氏度
# 2020-05-23T21:00:00+08:00: 27攝氏度
# 2020-05-24T00:00:00+08:00: 27攝氏度
# 2020-05-24T03:00:00+08:00: 26攝氏度
# 2020-05-24T06:00:00+08:00: 26攝氏度
# 2020-05-24T09:00:00+08:00: 28攝氏度
